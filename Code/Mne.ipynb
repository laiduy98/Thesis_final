# %%
# %matplotlib qt

# %%
import numpy as np
import mne
import pandas as pd

EEGsignal = pd.read_csv('5_1.tdt', sep = '\t')

# %%
channel_names = ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz']
sfreq = 240
info = mne.create_info(channel_names, sfreq)

# %%
print(info)
# Out:
# <Info | 16 non-empty fields
#     bads : list | 0 items
#     ch_names : list | FP1, FP2, F3, F4, C3, C4, P3, P4, O1, ...
#     chs : list | 19 items (MISC: 19)
#     comps : list | 0 items
#     custom_ref_applied : bool | False
#     dev_head_t : Transform | 3 items
#     events : list | 0 items
#     highpass : float | 0.0 Hz
#     hpi_meas : list | 0 items
#     hpi_results : list | 0 items
#     lowpass : float | 120.0 Hz
#     meas_date : NoneType | unspecified
#     nchan : int | 19
#     proc_history : list | 0 items
#     projs : list | 0 items
#     sfreq : float | 240.0 Hz
#     acq_pars : NoneType
#     acq_stim : NoneType
#     ctf_head_t : NoneType
#     description : NoneType
#     dev_ctf_t : NoneType
#     dig : NoneType
#     experimenter : NoneType
#     file_id : NoneType
#     gantry_angle : NoneType
#     hpi_subsystem : NoneType
#     kit_system_id : NoneType
#     line_freq : NoneType
#     meas_id : NoneType
#     proj_id : NoneType
# ...

# %%
EEGsignalValues = EEGsignal.values

# %%
EEGsignalValues = EEGsignalValues.transpose()
raw = mne.io.RawArray(EEGsignalValues, info)
# Out:
# Creating RawArray with float64 data, n_channels=19, n_times=16569
#     Range : 0 ... 16568 =      0.000 ...    69.033 secs
# Ready.

# %%
raw.plot()

# %%
raw.notch_filter(np.arange(60, 241, 60), picks=picks, fir_design='firwin')
raw.plot_psd(area_mode='range', tmax=10.0, picks=picks, average=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-218570d266e9> in <module>
# ----> 1 raw.notch_filter(np.arange(60, 241, 60), picks=picks, fir_design='firwin')
#       2 raw.plot_psd(area_mode='range', tmax=10.0, picks=picks, average=False)
#
# NameError: name 'picks' is not defined
